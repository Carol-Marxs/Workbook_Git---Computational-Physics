# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
np.random.seed(42)

def generate_data(nx, qtde, pmax):
    x = np.linspace(-1, 1, nx).reshape(-1, 1)
    y = []
    dy = []
    
    for _ in range(qtde//2):
        # potencial de grau 5
        p = 7
        coeffs = np.random.randn(p + 1)
        polinomio = np.polyval(coeffs, x)
        noise = 0.01 * np.random.randn(len(x)).reshape(-1, 1)
        y.append(polinomio / np.max(np.abs(polinomio)) + noise)
    
        # derivada
        noise = 0.01 * np.random.randn(len(x)).reshape(-1, 1)
        der=np.polyval(np.polyder(coeffs), x)
        dy.append(((der))/ np.max(np.abs(der)) + noise)
    
    for _ in range(qtde):
        # Polinômio de grau 4 (par) – tipo "cosseno"
        p = 6
        coeffs = np.random.randn(p + 1)
        polinomio = np.polyval(coeffs, x)
        noise = 0.01 * np.random.randn(len(x)).reshape(-1, 1)
        y.append(polinomio / np.max(np.abs(polinomio)) + noise)

        der = np.polyval(np.polyder(coeffs), x)
        noise = 0.01 * np.random.randn(len(x)).reshape(-1, 1)
        dy.append(der / np.max(np.abs(der)) + noise)


    # empilha dados
    y = np.hstack(y).T
    dy = np.hstack(dy).T
    return y, dy

# gerar dados
y, dy = generate_data(50, 10000, 10)

print(y.shape)
print(dy.shape)
# Out:
# (15000, 50)
# (15000, 50)

# %%
# separa os os dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(y, dy, test_size=0.2, random_state=42)

neurons = 10
layers = 10

# define modelo
model = MLPRegressor(
    hidden_layer_sizes=tuple([neurons] * layers), 
    activation='tanh',
    solver='adam',
    max_iter=1000, 
    random_state=42,
    learning_rate='adaptive',
    learning_rate_init = 0.01,
    n_iter_no_change = 50,
    tol = 1e-10,
    verbose=True)

# treinamento
model.fit(X_train, y_train)

# teste
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
# Out:
# Iteration 1, loss = 0.03204359
# Iteration 2, loss = 0.00886565
# Iteration 3, loss = 0.00747515
# Iteration 4, loss = 0.00433942
# Iteration 5, loss = 0.00293872
# Iteration 6, loss = 0.00290576
# Iteration 7, loss = 0.00269423
# Iteration 8, loss = 0.00261178
# Iteration 9, loss = 0.00245730
# Iteration 10, loss = 0.00225149
# Iteration 11, loss = 0.00223520
# Iteration 12, loss = 0.00228067
# Iteration 13, loss = 0.00223883
# Iteration 14, loss = 0.00224297
# Iteration 15, loss = 0.00217833
# Iteration 16, loss = 0.00212929
# Iteration 17, loss = 0.00225667
# Iteration 18, loss = 0.00211174
# Iteration 19, loss = 0.00213033
# Iteration 20, loss = 0.00208205
# Iteration 21, loss = 0.00201552
# Iteration 22, loss = 0.00214842
# Iteration 23, loss = 0.00204890
# Iteration 24, loss = 0.00207230
# Iteration 25, loss = 0.00204129
# Iteration 26, loss = 0.00209894
# Iteration 27, loss = 0.00201403
# Iteration 28, loss = 0.00203024
# Iteration 29, loss = 0.00169644
# Iteration 30, loss = 0.00147256
# Iteration 31, loss = 0.00151341
# Iteration 32, loss = 0.00127162
# Iteration 33, loss = 0.00113532
# Iteration 34, loss = 0.00112555
# Iteration 35, loss = 0.00134805
# Iteration 36, loss = 0.00108202
# Iteration 37, loss = 0.00101979
# Iteration 38, loss = 0.00105117
# Iteration 39, loss = 0.00120702
# Iteration 40, loss = 0.00111262
# Iteration 41, loss = 0.00096747
# Iteration 131, loss = 0.00083318
# Iteration 132, loss = 0.00095147
# Iteration 133, loss = 0.00083000
# Iteration 134, loss = 0.00093788
# Iteration 135, loss = 0.00076036
# Iteration 136, loss = 0.00088686
# Iteration 137, loss = 0.00085279
# Iteration 138, loss = 0.00077304
# Iteration 139, loss = 0.00096694
# Iteration 140, loss = 0.00083789
# Iteration 141, loss = 0.00085337
# Iteration 142, loss = 0.00080720
# Iteration 143, loss = 0.00085739
# Iteration 144, loss = 0.00094929
# Iteration 145, loss = 0.00091148
# Iteration 146, loss = 0.00076513
# Iteration 147, loss = 0.00081520
# Iteration 148, loss = 0.00088625
# Iteration 149, loss = 0.00106210
# Iteration 150, loss = 0.00099738
# Iteration 151, loss = 0.00079367
# Iteration 152, loss = 0.00082776
# Iteration 153, loss = 0.00090994
# Iteration 154, loss = 0.00085243
# Iteration 155, loss = 0.00081118
# Iteration 156, loss = 0.00091503
# Iteration 157, loss = 0.00084591
# Iteration 158, loss = 0.00086679
# Iteration 159, loss = 0.00082399
# Iteration 160, loss = 0.00084110
# Iteration 161, loss = 0.00086833
# Iteration 162, loss = 0.00083906
# Iteration 163, loss = 0.00085358
# Iteration 164, loss = 0.00087145
# Iteration 165, loss = 0.00088612
# Iteration 166, loss = 0.00080945
# Iteration 167, loss = 0.00083704
# Iteration 168, loss = 0.00082655
# Iteration 169, loss = 0.00085638
# Iteration 170, loss = 0.00078327
# Iteration 171, loss = 0.00094114
# Iteration 172, loss = 0.00081606
# Iteration 173, loss = 0.00089643
# Iteration 174, loss = 0.00079698
# Training loss did not improve more than tol=0.000000 for 50 consecutive epochs. Stopping.
# Mean Squared Error: 0.0014837595532337536

# %%
plt.figure(figsize=(10, 4))

new_x = np.linspace(0, 1, y.shape[1]).reshape(1,-1)

# test 1
plt.subplot(131)
new_y = np.sin(2*np.pi*new_x)
new_dy = np.cos(2*np.pi*new_x)
predicted_derivative = model.predict(new_y)

plt.plot(new_x[0], new_y[0], label='Input', color='black')
plt.plot(new_x[0], new_dy[0], label='True dy/dx', color='blue')
plt.plot(new_x[0], predicted_derivative[0], label='Predicted dy/dx', color='red', linestyle='dashed')
plt.ylim(-1,1)
plt.xlabel('x')
plt.ylabel('dy/dx')
plt.legend()
plt.grid(True)

# test 2
plt.subplot(132)
new_y = np.cos(2*np.pi*new_x)
new_dy = -np.sin(2*np.pi*new_x)
predicted_derivative = model.predict(new_y)

plt.plot(new_x[0], new_y[0], label='Input', color='black')
plt.plot(new_x[0], new_dy[0], label='True dy/dx', color='blue')
plt.plot(new_x[0], predicted_derivative[0], label='Predicted dy/dx', color='red', linestyle='dashed')
plt.ylim(-1,1)
plt.xlabel('x')
plt.ylabel('dy/dx')
plt.legend()
plt.grid(True)

# test 3
plt.subplot(133)
new_y = new_x ** 2
new_dy = 2 * new_x
predicted_derivative = model.predict(new_y)

plt.plot(new_x[0], new_y[0], label='Input', color='black')
plt.plot(new_x[0], new_dy[0], label='True dy/dx', color='blue')
plt.plot(new_x[0], predicted_derivative[0], label='Predicted dy/dx', color='red', linestyle='dashed')
plt.ylim(-1,1)
plt.xlabel('x')
plt.ylabel('dy/dx')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
